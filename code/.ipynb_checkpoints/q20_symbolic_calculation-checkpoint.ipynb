# %%
# Now try to calculate the l=2 mode of the remote quadrupole field
from sympy import *
import numpy as np

# %%
A = Symbol('A')
B = Symbol('B')
r_H = Symbol('r_H')
chi_c = Symbol('chi_c')

chi_e = Symbol('chi_e')
chi_edec = Symbol('chi_edec')
theta_e = Symbol('theta_e')
D_psi = Symbol('D_psi')

# %%
class BubbleCollision_RF_symbolic():
    def __init__(self, A, B, r_H, chi_c, chi_e, chi_edec, theta_e):
        self.A = A
        self.B = B
        self.r_H = r_H
        self.chi_c = chi_c
        self.chi_e = chi_e
        self.chi_edec = chi_edec

    def Cos_theta_c(self, theta_e):
        return (self.chi_c - self.chi_e*cos(theta_e))/self.chi_edec
        
    def Delta_cos_theta_c_n(self, cos_theta_c, n):
        return 1 - cos_theta_c**n

    def RQF_SW(self, theta_e, D_psi):
        cos_theta_c = self.Cos_theta_c(theta_e)
        sin_theta_e = sin(theta_e)
        cos_theta_e = cos(theta_e)
        
        return (Symbol('2')*D_psi-Symbol('3/2'))*5*np.sqrt(6)/16*sin_theta_e**2*\
        (A/self.r_H*(3/4*self.chi_edec*self.Delta_cos_theta_c_n(cos_theta_c, 4)\
                     + (self.chi_e*cos_theta_e-self.chi_c)*self.Delta_cos_theta_c_n(cos_theta_c, 3) \
                     -1/2*self.chi_edec*self.Delta_cos_theta_c_n(cos_theta_c, 2) - \
                     (self.chi_e*cos_theta_e -self.chi_c)* self.Delta_cos_theta_c_n(cos_theta_c, 1)) + \
         B/(self.r_H**2)*(3/5*self.chi_edec**2*self.Delta_cos_theta_c_n(cos_theta_c, 5) + \
                          3/2*self.chi_edec*(self.chi_e*cos_theta_e-self.chi_c)*self.Delta_cos_theta_c_n(cos_theta_c, 4) + \
                          1/3*(-self.chi_edec**2 + \
                               3*(self.chi_e*cos_theta_e-self.chi_c)**2)*self.Delta_cos_theta_c_n(cos_theta_c,3) - \
                          self.chi_edec*(self.chi_e*cos_theta_e-self.chi_c)*self.Delta_cos_theta_c_n(cos_theta_c, 2) - \
                          (self.chi_e*cos_theta_e-self.chi_c)**2*self.Delta_cos_theta_c_n(cos_theta_c, 1)))

    def Y_s2_l2_m0(self, theta_e):
        return Symbol('3/4')*sqrt(5)/(sqrt(6)*sqrt(pi))*sin(theta_e)**2

# %%
BC_sym = BubbleCollision_RF_symbolic(A, B, r_H, chi_c, chi_e, chi_edec, theta_e)
BC_sym.RQF_SW(theta_e, D_psi)*BC_sym.Y_s2_l2_m0(theta_e)
# Out:
# sqrt(30)*3/4*(0.765465544619743*2*D_psi - 0.765465544619743*3/2)*(A*(0.75*chi_edec*(1 - (chi_c - chi_e*cos(theta_e))**4/chi_edec**4) - 0.5*chi_edec*(1 - (chi_c - chi_e*cos(theta_e))**2/chi_edec**2) + (1 - (chi_c - chi_e*cos(theta_e))**3/chi_edec**3)*(-chi_c + chi_e*cos(theta_e)) - (1 - (chi_c - chi_e*cos(theta_e))/chi_edec)*(-chi_c + chi_e*cos(theta_e)))/r_H + B*(0.6*chi_edec**2*(1 - (chi_c - chi_e*cos(theta_e))**5/chi_edec**5) + 1.5*chi_edec*(1 - (chi_c - chi_e*cos(theta_e))**4/chi_edec**4)*(-chi_c + chi_e*cos(theta_e)) - chi_edec*(1 - (chi_c - chi_e*cos(theta_e))**2/chi_edec**2)*(-chi_c + chi_e*cos(theta_e)) + (1 - (chi_c - chi_e*cos(theta_e))**3/chi_edec**3)*(-0.333333333333333*chi_edec**2 + 1.0*(-chi_c + chi_e*cos(theta_e))**2) - (1 - (chi_c - chi_e*cos(theta_e))/chi_edec)*(-chi_c + chi_e*cos(theta_e))**2)/r_H**2)*sin(theta_e)**4/(6*sqrt(pi))

# %%
integrate(BC_sym.RQF_SW(theta_e, D_psi)*BC_sym.Y_s2_l2_m0(theta_e), theta_e)
# Out:
# sqrt(30)*3/4*(0.765465544619743*2*D_psi - 0.765465544619743*3/2)*(0.09375*A*chi_c**4*theta_e*sin(theta_e)**4/(chi_edec**3*r_H) + 0.1875*A*chi_c**4*theta_e*sin(theta_e)**2*cos(theta_e)**2/(chi_edec**3*r_H) + 0.09375*A*chi_c**4*theta_e*cos(theta_e)**4/(chi_edec**3*r_H) - 0.15625*A*chi_c**4*sin(theta_e)**3*cos(theta_e)/(chi_edec**3*r_H) - 0.09375*A*chi_c**4*sin(theta_e)*cos(theta_e)**3/(chi_edec**3*r_H) - 0.2*A*chi_c**3*chi_e*sin(theta_e)**5/(chi_edec**3*r_H) + 0.09375*A*chi_c**2*chi_e**2*theta_e*sin(theta_e)**6/(chi_edec**3*r_H) + 0.28125*A*chi_c**2*chi_e**2*theta_e*sin(theta_e)**4*cos(theta_e)**2/(chi_edec**3*r_H) + 0.28125*A*chi_c**2*chi_e**2*theta_e*sin(theta_e)**2*cos(theta_e)**4/(chi_edec**3*r_H) + 0.09375*A*chi_c**2*chi_e**2*theta_e*cos(theta_e)**6/(chi_edec**3*r_H) + 0.09375*A*chi_c**2*chi_e**2*sin(theta_e)**5*cos(theta_e)/(chi_edec**3*r_H) - 0.25*A*chi_c**2*chi_e**2*sin(theta_e)**3*cos(theta_e)**3/(chi_edec**3*r_H) - 0.09375*A*chi_c**2*chi_e**2*sin(theta_e)*cos(theta_e)**5/(chi
# ...

# %%
Cos_theta_c_num = lambdify(theta_e, BC_sym.Cos_theta_c(theta_e))
Cos_theta_c_num(1)
# Out:
# (chi_c - 0.54030230586814*chi_e)/chi_edec

# %%
Delta_cos_theta_c_n_num = lambdify((theta_e, Symbol('n')) , BC_sym.Delta_cos_theta_c_n(theta_e, Symbol('n')))

# %%
Delta_cos_theta_c_n_num(np.pi, 1)
# Out:
# -2.141592653589793
