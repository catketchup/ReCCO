# %%
import numpy as np
import density_field_library as DFL
import config as conf
import matplotlib.pyplot as plt
from math import pi
import Pk_library as PKL
import config as conf
import my_remote_spectra as remote_spectra
import importlib
import estim
from estim import estimator
import redshifts

# %%
importlib.reload(conf)
importlib.reload(estim)
zb = redshifts.binning(conf_module = conf) 
Omega_b = conf.Omega_b
Omega_c = conf.Omega_c
w = conf.w
wa = conf.wa
Omega_K = conf.Omega_K
h = conf.h
zbins_acentral = 1/(1+zb.zbins_zcentral)
Dv_central = -remote_spectra.Dv_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(zbins_acentral)

# %%
As= conf.As
ns = conf.ns
k_in = np.linspace(2e-4, 1.5e-2, 100)
k_pivot = 0.05
Pk_in = 2*pi**2*As*(k_in/k_pivot)**(ns-1)*1e-9
# P_psi = remote_spectra.Ppsi(k_test, As, ns)
if 1:
    plt.plot(k_in, Pk_in)
    plt.xscale('log')
    plt.yscale('log')

# %%
grid              = 128  #grid size
BoxSize           = 30000.0 #Mpc/h
seed              = 1      #value of the initial random seed
Rayleigh_sampling = 0      #whether sampling the Rayleigh distribution for modes amplitudes
threads           = 1      #number of openmp threads
verbose           = True   #whether to print some information

# read power spectrum; k and Pk have to be floats, not doubles
# k, Pk = np.loadtxt('my_Pk.txt', unpack=True)

k_in, Pk_in = k_in.astype(np.float32), Pk_in.astype(np.float32)
# generate a 2D Gaussian density field
# df_2D = DFL.gaussian_field_2D(grid, k, Pk, Rayleigh_sampling, seed,
                              # BoxSize, threads, verbose)
# Pk_in = Pk_in/k_in**3

# generate a 3D Gaussian density field
psi_x = DFL.gaussian_field_3D(grid, k_in, Pk_in, Rayleigh_sampling, seed,
                              BoxSize, threads, verbose)
# Out:
# delta(k) field generated
# time taken = 0.06860 seconds

# %%
Pk = PKL.Pk(psi_x, BoxSize)
# 1D P(k)
k1D      = Pk.k1D
Pk1D     = Pk.Pk1D
Nmodes1D = Pk.Nmodes1D

# 2D P(k)
kpar     = Pk.kpar
kper     = Pk.kper
Pk2D     = Pk.Pk2D
Nmodes2D = Pk.Nmodes2D

# 3D P(k)
k       = Pk.k3D
Pk0     = Pk.Pk[:,0] #monopole
Pk2     = Pk.Pk[:,1] #quadrupole
Pk4     = Pk.Pk[:,2] #hexadecapole
Pkphase = Pk.Pkphase #power spectrum of the phases
Nmodes  = Pk.Nmodes3D
# Out:
# Computing power spectrum of the field...
# Time to complete loop = 0.05
# Time taken = 0.06 seconds

# %%
k/(2*pi)
# Out:
# array([4.72140631e-05, 7.99972277e-05, 1.13784653e-04, 1.47677791e-04,
#        1.82237704e-04, 2.14747062e-04, 2.48107526e-04, 2.81610088e-04,
#        3.15411274e-04, 3.48879562e-04, 3.81793234e-04, 4.15280920e-04,
#        4.49368621e-04, 4.82603126e-04, 5.15703915e-04, 5.48958842e-04,
#        5.82282388e-04, 6.15687229e-04, 6.49176920e-04, 6.82677761e-04,
#        7.15932411e-04, 7.49062506e-04, 7.82582668e-04, 8.15862761e-04,
#        8.49175201e-04, 8.82774733e-04, 9.16305749e-04, 9.49499936e-04,
#        9.82704154e-04, 1.01583655e-03, 1.04930316e-03, 1.08275110e-03,
#        1.11617447e-03, 1.14958131e-03, 1.18289274e-03, 1.21627270e-03,
#        1.24944138e-03, 1.28274140e-03, 1.31613527e-03, 1.34936455e-03,
#        1.38270327e-03, 1.41608502e-03, 1.44959561e-03, 1.48307456e-03,
#        1.51641042e-03, 1.54957299e-03, 1.58276930e-03, 1.61615619e-03,
#        1.64952381e-03, 1.68288748e-03, 1.71632031e-03, 1.74973258e-03,
#        1.78315948e-03, 1.81632946e-03, 1.84963413e-03, 1.88302135e-03,
#        1.91618145e-03, 1.94952449e-03, 1.98288374e-03, 2.01630959e-03,
#        2.04967156e-03, 2.08288206e-03, 2.11637055e-03, 2.14968229e-03,
#        2.18299881e-03, 2.21635268e-03, 2.24954989e-03, 2.28299133e-03,
#        2.31633821e-03, 2.34953298e-03, 2.38283005e-03, 2.41619492e-03,
#        2.44962621e-03, 2.48301138e-03, 2.51644809e-03, 2.54975239e-03,
#        2.58285871e-03, 2.61621667e-03, 2.64965373e-03, 2.68280826e-03,
#        2.71595971e-03, 2.74943002e-03, 2.78287204e-03, 2.81625061e-03,
#        2.84940980e-03, 2.88254322e-03, 2.91594957e-03, 2.94933988e-03,
#        2.98237053e-03, 3.01589288e-03, 3.04929259e-03, 3.08229058e-03,
#        3.11552617e-03, 3.14940039e-03, 3.18310180e-03, 3.21549113e-03,
#        3.24882702e-03, 3.28305181e-03, 3.31584298e-03, 3.34815214e-03,
#        3.38227384e-03, 3.41799409e-03, 3.45122784e-03, 3.47994242e-03,
#        3.51373948e-03, 3.55105394e-03, 3.58676414e-03, 3.61290102e-03,
#        3.64378679e-03, 3.68068353e-03])

# %%
kF,kN,kmax_par,kmax_per,kmax = PKL.frequencies(BoxSize, grid)

# %%
k3D = np.zeros(kmax+1, dtype=np.float64)

# %%
print(kF/(2*pi))
print(kN/(2*pi))
# Out:
# 3.3333333333333335e-05
# 0.0021333333333333334

# %%
plt.plot(k_in, Pk_in, label='Pk input')
plt.plot(k[:20], Pk0[:20], label='Pk output')

plt.xscale('log')
plt.yscale('log')
plt.legend()

# %%
d = BoxSize/grid
SampleRate = 1/d
Max_k = 1/2*SampleRate
Min_k = 1/BoxSize
print(Min_k)
print(Max_k)
print(2*pi*Min_k)
print(2*pi*Max_k)
# Out:
# 3.3333333333333335e-05
# 0.0021333333333333334
# 0.00020943951023931956
# 0.013404128655316452

# %%
plt.plot(k_in, Pk_in, label='Pk input')
plt.plot(k[:20], Pk0[:20], label='Pk output')

plt.xscale('log')
plt.yscale('log')
plt.axvline(x=2*pi*Max_k, linestyle = '--')
plt.axvline(x=2*pi*Min_k, linestyle = '--')
plt.legend()

# %%
# 3-d real space axes
d = BoxSize/grid

x = np.arange(-BoxSize/2, BoxSize/2, d)
y = np.arange(-BoxSize/2, BoxSize/2, d)
z = np.arange(-BoxSize/2, BoxSize/2, d)
# 3-d meshgrid coordinate
# xx, yy = np.meshgrid(x, y)
xx, yy, zz = np.meshgrid(x, y, z)
rr = np.sqrt(xx**2 + yy**2 + zz**2)
print(xx.shape)
# Out:
# (128, 128, 128)

# %%
k_x = np.fft.fftfreq(grid, d)
k_y = np.fft.fftfreq(grid, d)
k_z = np.fft.fftfreq(grid, d)
kk_x, kk_y, kk_z = np.meshgrid(k_x, k_y, k_z)
kk_x_s, kk_y_s, kk_z_s = np.fft.fftshift(kk_x), np.fft.fftshift(kk_y), np.fft.fftshift(kk_z)

kk  = np.sqrt(kk_x_s**2 + kk_y_s**2 + kk_z_s**2)
kk.shape
# Out:
# (128, 128, 128)

# %%
if 0:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    fig.colorbar(ax.scatter(xx,yy,zz,c=df_3D, s=0.1))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\Psi (x)_{Pylian}$');

# %%
g_psi_x = np.gradient(psi_x)

# %%
psi_k = np.fft.fftn(psi_x)

# %%
a = 0.8
D_psi = remote_spectra.Dpsi_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(a)
psi_x_a = D_psi*psi_x

# %%
Pk_a = PKL.Pk(psi_x_a, BoxSize)
# 3D P(k)
k_a       = Pk_a.k3D
Pk0_a     = Pk_a.Pk[:,0]
# Out:
# Computing power spectrum of the field...
# Time to complete loop = 0.05
# Time taken = 0.06 seconds

# %%
# plt.plot(k_in[2:400], Pk_in[2:400], label='Pk input')
plt.plot(k, Pk0, label='Pk output')
plt.plot(k_a, Pk0_a, label='Pk_a output')
plt.plot(k_in[2:], Pk_in[2:], label='Pk input')

plt.xscale('log')
plt.yscale('log')
plt.legend()
