# %%
import numpy as np
import density_field_library as DFL
import matplotlib.pyplot as plt
from math import pi

import Pk_library as PKL
import config as config
import my_remote_spectra as remote_spectra
# import remote_spectra as remote_spectra
import kszpsz_config as kszpsz_config

import importlib
import estim
from estim import estimator
import redshifts
from scipy.interpolate import RegularGridInterpolator
from scipy.interpolate import interp1d
import healpy as hp
from classy import Class

# %%
importlib.reload(config)
importlib.reload(estim);

# %%
zb = redshifts.binning(conf_module = config) 
# import cosmological parameters
Omega_b = config.Omega_b
Omega_c = config.Omega_c
w = config.w
wa = config.wa
Omega_K = config.Omega_K
h = config.h
As= config.As
ns = config.ns

# %%
grid              = 128  #grid size
BoxSize           = 30000.0*h #Mpc/h
seed              = 1    #value of the initial random seed # varing seed
Rayleigh_sampling = 0     #whether sampling the Rayleigh distribution for modes amplitudes
threads           = 1      #number of openmp threads
verbose           = True   #whether to print some information

d = BoxSize/grid #Mpc/h
SampleRate = 1/d #h/Mpc
Max_k = 1/2*2*pi*SampleRate #h/Mpc, 2 from Nyquist theorem
Min_k = 2*pi/BoxSize #h/Mpc
print(d) #Mpc/h
print(Min_k) #h/Mpc
print(Max_k) #h/Mpc

# k calculated by pylian3
kF,kN,kmax_par,kmax_per,kmax = PKL.frequencies(BoxSize, grid)
print(kF) #h/Mpc
print(kN) #h/Mpc

# test the "variance" paper setup
if 0:
    L = 313000
    Resolution = 128
    Lambda_min = 484
    k_max = 1/2*2*pi/(L/Resolution)
    print(k_max)
    print(1/2*2*pi/Lambda_min)
    print(2*pi/Lambda_min)
# Out:
# 159.375
# 0.0003079992797637052
# 0.019711953904877132
# 0.0003079992797637052
# 0.019711953904877132

# %%
k_in = np.linspace(2e-4, 4e-2, 100)/h #h/Mpc
k_pivot = 0.05/h #h/Mpc
Pk_in = 2*pi**2*As*(k_in/k_pivot)**(ns-1)*1e-9/k_in**3 #(Mpc/h)^3


P_psi = remote_spectra.Ppsi(k_in, As, ns) #(Mpc/h)^3
plt.plot(k_in, Pk_in)
plt.plot(k_in, P_psi/(2/3)**2)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('k [h/Mpc]')
plt.ylabel('P(k) [(Mpc/h)^3]')
# Out:
# Text(0, 0.5, 'P(k) [(Mpc/h)^3]')

# %%
# read power spectrum; k and Pk have to be floats, not doubles
k_in, Pk_in = k_in.astype(np.float32), Pk_in.astype(np.float32)

# generate a 3D Gaussian density field
psi_x = DFL.gaussian_field_3D(grid, k_in, Pk_in, Rayleigh_sampling, seed,
                              BoxSize, threads, verbose)
# Out:
# delta(k) field generated
# time taken = 0.07336 seconds

# %%
Pk = PKL.Pk(psi_x, BoxSize, MAS='None')
# 3D P(k)
k       = Pk.k3D #h/Mpc
Pk0     = Pk.Pk[:,0] #monopole, (Mpc/h)^3
Pk2     = Pk.Pk[:,1] #quadrupole
Pk4     = Pk.Pk[:,2] #hexadecapole
Pkphase = Pk.Pkphase #power spectrum of the phases
Nmodes  = Pk.Nmodes3D
# Out:
# Computing power spectrum of the field...
# Time to complete loop = 0.03
# Time taken = 0.03 seconds

# %%
if 1:
    plt.plot(k_in, Pk_in, label='Pk input')
    # plt.plot(k[:20], Pk0[:20], label='Pk output')
    plt.plot(k, Pk0, label='Pk output')
    # plt.plot(k1D, Pk1D, label='Pk output')
    
    # shot_noise
    # shot_noise = BoxSize**3/grid**3*np.ones_like(k)
    # plt.plot(k, shot_noise)
    
    plt.xscale('log')
    plt.yscale('log')
    plt.axvline(x=Max_k, linestyle = '--')
    plt.axvline(x=Min_k, linestyle = '--')
    plt.xlabel('k [h/Mpc]')
    plt.ylabel('P(k) [(Mpc/h)^3]')
    plt.legend()

# %%
# 3-d real space axes
d = BoxSize/grid #Mpc/h
x = np.arange(-BoxSize/2, BoxSize/2, d) #Mpc/h
y = np.arange(-BoxSize/2, BoxSize/2, d) #Mpc/h
z = np.arange(-BoxSize/2, BoxSize/2, d) #Mpc/h
# 3-d meshgrid coordinate 
# xx, yy = np.meshgrid(x, y)
xx, yy, zz = np.meshgrid(x, y, z)
rr = np.sqrt(xx**2 + yy**2 + zz**2)
print(xx.shape)
# Out:
# (128, 128, 128)

# %%
if 1:
    k_x = np.fft.fftfreq(grid, d)
    k_y = np.fft.fftfreq(grid, d)
    k_z = np.fft.fftfreq(grid, d)
    kk_x, kk_y, kk_z = np.meshgrid(k_x, k_y, k_z)
    kk_x_s, kk_y_s, kk_z_s = np.fft.fftshift(kk_x), np.fft.fftshift(kk_y), np.fft.fftshift(kk_z)
    
    kk  = np.sqrt(kk_x**2 + kk_y**2 + kk_z**2)
    
    kk_s  = np.sqrt(kk_x_s**2 + kk_y_s**2 + kk_z_s**2)
    print(kk.shape)
# Out:
# (128, 128, 128)

# %%
if 0:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    fig.colorbar(ax.scatter(xx,yy,zz,c=psi_x, s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\Psi_{ini} (\mathbf{x})$');

# %%
# plt.plot(k_in[2:400], Pk_in[2:400], label='Pk input')
if 0:
    plt.plot(k, Pk0, label='Pk output')
    plt.plot(k_a, Pk0_a, label='Pk_a output')
    plt.plot(k_in, Pk_in, label='Pk input')
    plt.axvline(x=Max_k, linestyle = '--')
    plt.axvline(x=Min_k, linestyle = '--')
    
    plt.xscale('log')
    plt.yscale('log')
    plt.legend()
    # have to check carefully https://github.com/franciscovillaescusa/Pylians3/blob/master/density_field/Gaussian_density_field.py

# %% [markdown]
# # Import bubble collision parameters

# %%
# Now let's add the inhomogeneous potential psi_i_x where i for inhomogeneous
import param
importlib.reload(param)
A = param.A
B = param.B
z_c = param.z_c
x_c = remote_spectra.chifromz(z_c)*h #Mpc/h
r_H = param.r_H*h #Mpc/h
direction = param.direction
if 1:
    print(A)
    print(B)
    print(x_c)
    print(r_H) #Mpc/h
# Out:
# 0.0001
# 0
# 0.0
# 3000.0000000000005

# %%
x_xc = np.concatenate((np.zeros(int((BoxSize/2+x_c)/d)), np.arange(0, BoxSize/2-x_c, d)))

if direction == 'x':
    xx_xc, _, _ = np.meshgrid(x_xc, y, z)
elif direction == 'y':
    _, xx_xc, _ = np.meshgrid(y,x_xc, z)
else:
    _, _, xx_xc = np.meshgrid(y, z, x_xc)

psi_i_x = A*(xx_xc/r_H) + B*(xx_xc/r_H)**2
g_psi_i = np.gradient(psi_i_x)

# %%
if 0:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    fig.colorbar(ax.scatter(xx,yy,zz,c=psi_x, s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\Psi_{ini} (\mathbf{x})$');

# %%
if 0:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    fig.colorbar(ax.scatter(xx,yy,zz,c=psi_i_x, s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\Psi_{i} (\mathbf{x})$');

# %%
if 0:
    print(direction)
    if direction == 'x':
        plt.plot(x,psi_i_x[0, :, 0])
    
    elif direction == 'y':
        plt.plot(x,psi_i_x[:, 0, 0])
    
    elif direction == 'z':
        plt.plot(x,psi_i_x[0, 0, :])
    
    plt.xlabel(r'$x\ [Mpc]$')
    plt.ylabel(r'$\psi$')

# %%
if 0:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    fig.colorbar(ax.scatter(xx,yy,zz,c=psi_x+psi_i_x, s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\Psi_{ini} (x) + \Psi_{i} (x)$');

# %%
if 0:
    Pk_test = PKL.Pk(psi_x+np.float32(psi_i_x), BoxSize)
    # 3D P(k)
    k_test       = Pk_test.k3D
    Pk0_test     = Pk_test.Pk[:,0] #monopole
    
    plt.plot(k_in, Pk_in, label='Pk input')
    # plt.plot(k[:20], Pk0[:20], label='Pk output')
    plt.plot(k, Pk0, label='Pk output')
    plt.plot(k, Pk0_test, label='Pk_test output')
    
    plt.xscale('log')
    plt.yscale('log')
    plt.axvline(x=Max_k, linestyle = '--')
    plt.axvline(x=Min_k, linestyle = '--')
    plt.legend()
if 0:
    plt.plot(k, Pk0_test/Pk0)
    plt.axvline(x=Max_k, linestyle = '--')
    plt.axvline(x=Min_k, linestyle = '--')
    plt.xlabel(r'$k[Mpc^{-1}]$')

# %%
# now we consider the evolution of effective velocity field, i.e., work on the Fourier kernel of SW, ISW and Doppler effects
# these have been tested in V_eff_calculation.ipynb
# I would like to figure out how to do multiplication in Fourier space at first
# construct the k-spac

# %% [markdown]
# # Choose the Ze of remote dipole field

# %%
z_e = 1
a_e = 1/(1+z_e)
ks = kszpsz_config.kaux #/Mpc

# %%
#'Best fitting' transfer function for subhorizon modes from Eq. 7.70 in Dodelson
T = remote_spectra.T(ks, Omega_b, Omega_c, w, wa, Omega_K, h)

# Fourier kernels for different contributions
G_SW_Veff = T*remote_spectra.G_SW_ksz(ks, z_e, Omega_b, Omega_c, w, wa, Omega_K, h)
G_localDopp_Veff = T*remote_spectra.G_localDopp_ksz(ks, z_e, Omega_b, Omega_c, w, wa, Omega_K, h)
G_Dopp_Veff = T*remote_spectra.G_Dopp_ksz(ks, z_e, Omega_b, Omega_c, w, wa, Omega_K, h)
G_ISW_Veff = T*remote_spectra.G_ISW_ksz(ks, z_e, Omega_b, Omega_c, w, wa, Omega_K, h)

# total Fourier kernel for effective velocity field (remote dipole field)
G_Veff = G_SW_Veff + G_Dopp_Veff + G_ISW_Veff

# %%
if 0:
    num_k_max = 200
    plt.plot(ks[:num_k_max], G_SW_Veff[:num_k_max], '--', label=r'$SW$')
    # plt.plot(ks, G_SW_Veff_w0wa, '--', label=r'$SW\ w_{0}w_{a}$')
    
    plt.plot(ks[:num_k_max], G_Dopp_Veff[:num_k_max],'--', label=r'$Doppler$')
    # plt.plot(ks, G_Dopp_Veff_w0wa, label=r'$Doppler\ w_{0}w_{a}$')
    
    plt.plot(ks[:num_k_max], G_ISW_Veff[:num_k_max], '--', label=r'$ISW$')
    # plt.plot(ks, G_ISW_Veff_w0wa, '-.', label=r'$ISW\ w_{0}w_{a}$')
    
    plt.plot(ks[:num_k_max], G_SW_Veff[:num_k_max]+G_Dopp_Veff[:num_k_max]+G_ISW_Veff[:num_k_max], '-', label=r'$SW+Dopp+ISW$')
    
    plt.axhline(y=0, linestyle = ':', c='k')
    plt.legend()
    plt.xlabel(r'$k$')
    plt.title(r'$Fourier\ kernel, z_{e}=%s$' %z_e)
    plt.xlabel(r'$k[Mpc^{-1}]$')

# %%
if 0:
    num_k_max = 30
    plt.plot(ks[:num_k_max], (G_Dopp_Veff + G_SW_Veff)[:num_k_max], '--', label=r'$Dopp + SW$')
    # plt.plot(ks, G_SW_Veff_w0wa, '--', label=r'$SW\ w_{0}w_{a}$')
    
    plt.plot(ks[:num_k_max], G_ISW_Veff[:num_k_max], '--', label=r'$ISW$')
    # plt.plot(ks, G_ISW_Veff_w0wa, '-.', label=r'$ISW\ w_{0}w_{a}$')
    
    plt.axhline(y=0, linestyle = ':', c='k')
    plt.legend()
    plt.xlabel(r'$k$')
    plt.title(r'$Fourier\ kernel, z_{e}=%s$' %z_e)
    plt.xlabel(r'$k[Mpc^{-1}]$')

# %%
# get potential gradient and re-arrange the orders, # h/Mpc
g_psi_x = np.array([np.gradient(psi_x, d)[1], np.gradient(psi_x, d)[0], np.gradient(psi_x, d)[2]])
g_psi_i_x = np.array([np.gradient(psi_i_x, d)[1], np.gradient(psi_i_x, d)[0], np.gradient(psi_i_x, d)[2]])

g_psi_k = np.fft.fftn(g_psi_x)
g_psi_i_k = np.fft.fftn(g_psi_i_x)

g_psi_k = np.array([np.fft.fftn(g_psi_x[0]), np.fft.fftn(g_psi_x[1]), np.fft.fftn(g_psi_x[2])])
g_psi_i_k = np.array([np.fft.fftn(g_psi_i_x[0]), np.fft.fftn(g_psi_i_x[1]), np.fft.fftn(g_psi_i_x[2])])

# %%
if 0:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    fig.colorbar(ax.scatter(xx,yy,zz,c=g_psi_x[1], s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\nabla_x \Psi_{ini} (\mathbf{x})$');

# %%
if 0:
    fig = plt.figure(figsize=(16,6))
    ax = fig.add_subplot(131, projection='3d')

    fig.colorbar(ax.scatter(xx,yy,zz,c=g_psi_i_x[0], s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\nabla_x \Psi_i (\mathbf{x})$');

    ax = fig.add_subplot(132, projection='3d')
    fig.colorbar(ax.scatter(xx,yy,zz,c=g_psi_i_x[1], s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\nabla_y \Psi_i (\mathbf{x})$');

    ax = fig.add_subplot(133, projection='3d')
    fig.colorbar(ax.scatter(xx,yy,zz,c=g_psi_i_x[2], s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$\nabla_z \Psi_i (\mathbf{x})$');

# %% [markdown]
# # Choose different primoridial scalar potential scenarios

# %%
def ThreeDEvolve(G_itp, input_field_k, kk):
    kk[0,0,0] = np.mean(kk)
    output_field_k = G_itp(kk.flatten()).reshape(kk.shape)*input_field_k/kk
    
    return np.fft.ifftn(output_field_k)

# xyz direction V_eff FFT component, labeled by k1, k2, k3
G_SW_Veff_itp = interp1d(ks, G_SW_Veff)

G_ISW_Veff_itp = interp1d(ks, G_ISW_Veff)

G_localDopp_Veff_itp = interp1d(ks, G_localDopp_Veff)
G_Dopp_Veff_itp = interp1d(ks, G_Dopp_Veff)

G_Veff_itp = interp1d(ks, G_Veff)

# PriPerturbation = 'Gaussian'
PriPerturbation = 'BubbleCollision'
# PriPerturbation = 'Both'

if PriPerturbation == 'Gaussian':
    g_field_x = g_psi_x
    g_field_k = g_psi_k
if PriPerturbation == 'BubbleCollision':
    g_field_x = g_psi_i_x
    g_field_k = g_psi_i_k
elif PriPerturbation == 'Both':
    g_field_x = g_psi_x + g_psi_i_x 
    g_field_k = g_psi_k+g_psi_i_k

# %%
# xyz direction V_eff component, labeled by x1, x2, x3
V_eff_x1 = ThreeDEvolve(G_Veff_itp, g_field_k[0], kk)
V_eff_x2 = ThreeDEvolve(G_Veff_itp, g_field_k[1], kk)
V_eff_x3 = ThreeDEvolve(G_Veff_itp, g_field_k[2], kk)

# xyz direction V_eff_localDopp component, labeled by x1, x2, x3
V_eff_localDopp_x1 = ThreeDEvolve(G_localDopp_Veff_itp, g_field_k[0], kk)
V_eff_localDopp_x2 = ThreeDEvolve(G_localDopp_Veff_itp, g_field_k[1], kk)
V_eff_localDopp_x3 = ThreeDEvolve(G_localDopp_Veff_itp, g_field_k[2], kk)

# xyz direction V_eff_Dopp component, labeled by x1, x2, x3
V_eff_Dopp_x1 = ThreeDEvolve(G_Dopp_Veff_itp, g_field_k[0], kk)
V_eff_Dopp_x2 = ThreeDEvolve(G_Dopp_Veff_itp, g_field_k[1], kk)
V_eff_Dopp_x3 = ThreeDEvolve(G_Dopp_Veff_itp, g_field_k[2], kk)

# xyz direction V_eff_SW component, labeled by x1, x2, x3
V_eff_SW_x1 = ThreeDEvolve(G_SW_Veff_itp, g_field_k[0], kk)
V_eff_SW_x2 = ThreeDEvolve(G_SW_Veff_itp, g_field_k[1], kk)
V_eff_SW_x3 = ThreeDEvolve(G_SW_Veff_itp, g_field_k[2], kk)

# xyz direction V_eff_SW component, labeled by x1, x2, x3
V_eff_ISW_x1 = ThreeDEvolve(G_ISW_Veff_itp, g_field_k[0], kk)
V_eff_ISW_x2 = ThreeDEvolve(G_ISW_Veff_itp, g_field_k[1], kk)
V_eff_ISW_x3 = ThreeDEvolve(G_ISW_Veff_itp, g_field_k[2], kk)

# %%
if 1:
    print(direction)
    if direction == 'x':
        D_v = remote_spectra.Dv_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(a_e)
        plt.plot(x,-g_field_x[0][0, :, 0]*D_v, label='V approx evolution')
        plt.plot(x,V_eff_localDopp_x1.real[0, :, 0], label='V accurate evoluation')
        plt.legend()
    
    elif direction == 'y':
        D_v = remote_spectra.Dv_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(a_e)
        plt.plot(x,-g_field_x[1][:, 0, 0]*D_v, label='V approx evolution')
        plt.plot(x,V_eff_localDopp_x2.real[:, 0, 0], label='V accurate evoluation')
        plt.legend()
    
    elif direction == 'z':
        D_v = remote_spectra.Dv_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(a_e)
        plt.plot(x,-g_field_x[2].real[0, 0, :]*D_v, label='V approx evolution')
        plt.plot(x,V_eff_localDopp_x3.real[0, 0, :], label='V accurate evolution')
        plt.legend()
    plt.xlabel(r'$x\ [Mpc/h]$')
    plt.ylabel(r'$v/c$', rotation=0)
# Out:
# x

# %%
if 0:
    print(direction)
    if direction == 'x':
        D_v = remote_spectra.Dv_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(a_e)
        # plt.plot(x,g_field_x[0][0, :, 0]*D_v, label='V approx evolution')
        plt.plot(x,V_eff_localDopp_x1.real[0, :, 0], label='V accurate evoluation')
        plt.plot(x,V_eff_x1.real[0, :, 0], label=r'$V_{eff} \ accurate evoluation$')
        plt.legend()
    
    elif direction == 'y':
        D_v = remote_spectra.Dv_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(a_e)
        # plt.plot(x,g_field_x[1][:, 0, 0]*D_v, label='approx evolution')
        plt.plot(x,V_eff_localDopp_x2.real[:, 0, 0], label='accurate evoluationj')
        plt.plot(x,V_eff_x1.real[:, 0, 0], label=r'$V_{eff} \ accurate evoluation$')
        plt.legend()
    
    elif direction == 'z':
        D_v = remote_spectra.Dv_inter(Omega_b, Omega_c, w, wa, Omega_K, h)(a_e)
        # plt.plot(x,g_field_x[2].real[0, 0, :]*D_v, label='approx evolution')
        plt.plot(x,V_eff_localDopp_x3.real[0, 0, :], label='accurate evolution')
        plt.plot(x,V_eff_x1.real[:, 0, 0], label=r'$V_{eff} \ accurate evoluation$')
        plt.legend()
    plt.xlabel(r'$x\ [Mpc]$')
    plt.ylabel(r'$v$')

# %%
if 0:
    fig = plt.figure(figsize=(16,6))
    ax = fig.add_subplot(131, projection='3d')

    fig.colorbar(ax.scatter(xx,yy,zz,c=V_eff_localDopp_x1.real, s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$V_{eff,x}(\mathbf{x}, \chi_e), z_{e} = %s$' %ze);

    ax = fig.add_subplot(132, projection='3d')

    fig.colorbar(ax.scatter(xx,yy,zz,c=V_eff_localDopp_x2.real, s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$V_{eff,y}(\mathbf{x}, \chi_e), z_{e} = %s$' %ze);


    ax = fig.add_subplot(133, projection='3d')
    fig.colorbar(ax.scatter(xx,yy,zz,c=V_eff_localDopp_x3.real, s=0.01))
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$V_{eff,z}(\mathbf{x}, \chi_e), z_{e} = %s$' %ze);

# %%
common_settings = {# LambdaCDM parameters
                   'h':0.67810,
                   'omega_b':0.02238280,
                   'omega_cdm':0.12038,
                   'A_s':2.100549e-09,
                   'n_s': 0.9660499,
                   'tau_reio':0.05430842,
                   'gauge':'newtonian'
                   }
M = Class()
M.set(common_settings)
M.compute()

# %%
# compare the transfer functions generated by Class with Eq.(A.6), beforing doing 
# this, I need to get some background and thermodynamic quantities
background = M.get_background()
thermodynamics = M.get_thermodynamics()
tau_rec = M.get_current_derived_parameters(['tau_rec'])['tau_rec']

# %%
background_tau = background['config. time [Mpc]'] # read conformal times in background table
background_z = background['z'] # read redshift
background_a = 1/(1+background_z)

background_rho_m_over_r =\
    (background['(.)rho_b']+background['(.)rho_cdm'])\
    /(background['(.)rho_g']+background['(.)rho_ur']) # read rho_r / rho_m (to find time of equality)
background_tau_at_mr = interp1d(background_rho_m_over_r, background_z) # define interpolation function
z_eq = background_tau_at_mr(1.) # z for radiation-matter equility
a_eq = 1/(1+z_eq) # a for radiation-matter equility

# Omg_g and Omg_m interpolation functions
background_Omg_m_at_a_itp = interp1d(background_a, ((background['(.)rho_b']+background['(.)rho_cdm'])/\
                           background['(.)rho_tot']))
background_Omg_lambda_at_a_itp = interp1d(background_a, background['(.)rho_lambda']/background['(.)rho_tot'])
background_H_at_a_itp = interp1d(background_a, background['H [1/Mpc]'])
background_tau_at_a_itp = interp1d(background_a, background['config. time [Mpc]'])
background_a_at_tau_itp = interp1d(background['config. time [Mpc]'], background_a)

a_rec = background_a_at_tau_itp(tau_rec)
Z_rec = 1/a_rec-1

# %%
# try to plot the sphere on heapix plot
# https://healpy.readthedocs.io/en/latest/tutorial.html
NSIDE = 32
NPIX = hp.nside2npix(NSIDE)

# firstly obtain all the points at r_e = tau(a=1)-tau(a=a_e)
r_e = background_tau_at_a_itp(1) - background_tau_at_a_itp(a_e)
print(r_e)

theta_deg, phi_deg = np.degrees(hp.pix2ang(nside=NSIDE, ipix=np.arange(NPIX)))
theta = theta_deg * pi / 180.0
phi = phi_deg * pi / 180.0

x_e = r_e*np.sin(theta)*np.cos(phi)
y_e = r_e*np.sin(theta)*np.sin(phi)
z_e = r_e*np.cos(theta)

if 0:
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')

    ax.scatter(x_e,y_e,z_e, s=0.2)
    # ax.set_xlim([-r_o, r_o])
    # ax.set_ylim([-r_o, r_o])
    # ax.set_zlim([-r_o, r_o])
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    # ax.view_init(90, -90) 

# looks pretty good!
# Out:
# 3389.2627692740098

# %%
def ThreeDField_on_TwoDSurface(x_grid, y_grid, z_grid, field3D, x, y, z):
    return RegularGridInterpolator((x_grid, y_grid, z_grid), field3D)((y, x, z))

def TwoDVecField_Radial(field_x1, field_x2, field_x3, theta, phi):
    return field_x1*np.sin(theta)*np.cos(phi) + field_x2*np.sin(theta)*np.sin(phi) + field_x3*np.cos(theta)

# %%
V_eff_x1_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_x1.real,x_e, y_e, z_e)
V_eff_x2_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_x2.real,x_e, y_e, z_e)
V_eff_x3_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_x3.real,x_e, y_e, z_e)
V_eff_radial_chi = TwoDVecField_Radial(V_eff_x1_chi, V_eff_x2_chi, V_eff_x3_chi, theta, phi)

V_eff_SW_x1_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_SW_x1.real,x_e, y_e, z_e)
V_eff_SW_x2_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_SW_x2.real,x_e, y_e, z_e)
V_eff_SW_x3_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_SW_x3.real,x_e, y_e, z_e)
V_eff_SW_radial_chi = TwoDVecField_Radial(V_eff_SW_x1_chi, V_eff_SW_x2_chi, V_eff_SW_x3_chi, theta, phi)

V_eff_localDopp_x1_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_localDopp_x1.real,x_e, y_e, z_e)
V_eff_localDopp_x2_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_localDopp_x2.real,x_e, y_e, z_e)
V_eff_localDopp_x3_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_localDopp_x3.real,x_e, y_e, z_e)
V_eff_localDopp_radial_chi = TwoDVecField_Radial(V_eff_localDopp_x1_chi, V_eff_localDopp_x2_chi, V_eff_localDopp_x3_chi, theta, phi)

V_eff_Dopp_x1_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_Dopp_x1.real,x_e, y_e, z_e)
V_eff_Dopp_x2_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_Dopp_x2.real,x_e, y_e, z_e)
V_eff_Dopp_x3_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_Dopp_x3.real,x_e, y_e, z_e)
V_eff_Dopp_radial_chi = TwoDVecField_Radial(V_eff_Dopp_x1_chi, V_eff_Dopp_x2_chi, V_eff_Dopp_x3_chi, theta, phi)

V_eff_ISW_x1_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_ISW_x1.real,x_e, y_e, z_e)
V_eff_ISW_x2_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_ISW_x2.real,x_e, y_e, z_e)
V_eff_ISW_x3_chi = ThreeDField_on_TwoDSurface(x, y, z, V_eff_ISW_x3.real,x_e, y_e, z_e)
V_eff_ISW_radial_chi = TwoDVecField_Radial(V_eff_ISW_x1_chi, V_eff_ISW_x2_chi, V_eff_ISW_x3_chi, theta, phi)

# %%
# check https://stackoverflow.com/questions/11140163/plotting-a-3d-cube-a-sphere-and-a-vector
print(direction)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
# fig.colorbar(ax.scatter(x_e, y_e, z_e, c=V_eff_localDopp_radial_chi, alpha=0.4, label=r'$r_{edec}$', s=0.2))
fig.colorbar(ax.scatter(x_e, y_e, z_e, c=V_eff_radial_chi, alpha=0.4, label=r'$r_{edec}$', s=0.2));
# ax.scatter(x_e,y_e,z_e, color='r', s=10)
ax.set_xlabel(r'x')
ax.set_ylabel(r'y')
ax.set_zlabel(r'z')
ax.set_title(r'$V_{eff, r}(\mathbf{x}, r_e), z_e = %s$'%ze);
# ax.plot_surface(xx_c, yy_c, zz_c, alpha=0.2)
# ax.set_xlim([-r_o, r_o])
# ax.set_ylim([-r_o, r_o])
# ax.set_zlim([-r_o, r_o])
# ax.legend()
# check xy direction view
# ax.view_init(0, -90) 
# ax.view_init(90, -90) 
# ==========   ====  ====
# view plane   elev  azim
# ==========   ====  ====
# XY           90    -90
# XZ           0     -90
# YZ           0     0
# -XY          -90   90
# -XZ          0     90
# -YZ          0     180
# ==========   ====  ====
# Out:
# x

# %%
# see https://stackoverflow.com/questions/11140163/plotting-a-3d-cube-a-sphere-and-a-vector and \
# https://stackoverflow.com/questions/64656951/plotting-spheres-of-radius-r
# check https://stackoverflow.com/questions/11140163/plotting-a-3d-cube-a-sphere-and-a-vector
# Z_e = 2
# a_e = 1/(1+Z_e)
# firstly obtain all the points at r_e = tau(a=1)-tau(a=a_e)
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# then plot the LSS for an electron at this sphere and the LSS for us
# pick a certain point at the sphere with coordinate of (a_e, x_e, y_e, z_e)
# x_e, y_e, z_e = x_e_s[0, 0], y_e_s[0, 0], z_e_s[0, 0]

# get r_edec 
r_edec = background_tau_at_a_itp(a_e) - background_tau_at_a_itp(a_rec)
# u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:20j]
x_edec_s = r_edec*np.sin(theta)*np.cos(phi)
y_edec_s = r_edec*np.sin(theta)*np.sin(phi)
z_edec_s = r_edec*np.cos(theta)
# ax.scatter(x_e,y_e,z_e, color='r', s=10)

# get r_dec
r_dec = background_tau_at_a_itp(1) - background_tau_at_a_itp(a_rec)
# u, v = np.mgrid[0:2*np.pi:20j, 0:np.pi:20j]
x_dec_s = r_dec*np.sin(theta)*np.cos(phi)
y_dec_s = r_dec*np.sin(theta)*np.sin(phi)
z_dec_s = r_dec*np.cos(theta)

# ax.scatter(x_e, y_e, z_e, color='c', alpha=0.4, label=r'$r_{e}$', s=0.01)
# ax.scatter(x_e, y_e, z_e, c=V_eff_localDopp_radial_chi, alpha=0.4, label=r'$r_{e}$', s=0.01)
ax.scatter(x_e, y_e, z_e, c=V_eff_radial_chi, alpha=0.4, label=r'$r_{e}$', s=0.01)
ax.scatter(x_edec_s+x_e[0], y_edec_s+y_e[0], z_edec_s+z_e[0], alpha=0.4, label=r'$r_{edec}$', s=0.01)
ax.scatter(x_dec_s, y_dec_s, z_dec_s, color='y', alpha=0.4, label=r'$r_{dec}$', s=0.01)
ax.scatter(0,0,0, color='k', s=1)
ax.scatter(x_e[0],y_e[0],z_e[0], color='r', s=2)
yy_c, zz_c = np.meshgrid(y, z)
xx_c = x_c*np.ones_like(yy_c)
ax.plot_surface(xx_c, yy_c, zz_c, alpha=0.2)
# yy_c, zz_c = np.meshgrid(y, z)
# xx_c = x_c*np.ones_like(yy_c)
# ax.plot_surface(xx_c, yy_c, zz_c, alpha=0.2)

ax.set_xlim([-BoxSize/2, BoxSize/2])
ax.set_ylim([-BoxSize/2, BoxSize/2])
ax.set_zlim([-BoxSize/2,BoxSize/2])
ax.set_xlabel(r'x')
ax.set_ylabel(r'y')
ax.set_zlabel(r'z')
ax.set_title(r'$z_e=%s$' %ze)
ax.legend()
# ax.view_init(0, -90)

# %%
# check https://stackoverflow.com/questions/11140163/plotting-a-3d-cube-a-sphere-and-a-vector
if 0:
    print(direction)
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    fig.colorbar(ax.scatter(x_e, y_e, z_e, c=V_eff_SW_x1_chi, alpha=0.4, label=r'$r_{edec}$', s=0.2))
    # ax.scatter(x_e,y_e,z_e, color='r', s=10)
    ax.set_xlabel(r'x')
    ax.set_ylabel(r'y')
    ax.set_zlabel(r'z')
    ax.set_title(r'$V_{eff, x}(\mathbf{x}, r_e), z_e = %s$'%ze)
    # ax.plot_surface(xx_c, yy_c, zz_c, alpha=0.2)
    # ax.set_xlim([-r_o, r_o])
    # ax.set_ylim([-r_o, r_o])
    # ax.set_zlim([-r_o, r_o])
    # ax.legend()
    # check xy direction view
    ax.view_init(90, -90) 
    
    # ==========   ====  ====
    # view plane   elev  azim
    # ==========   ====  ====
    # XY           90    -90
    # XZ           0     -90
    # YZ           0     0
    # -XY          -90   90
    # -XZ          0     90
    # -YZ          0     180
    # ==========   ====  ====

# %%
if 0:
    plt.figure(figsize=(8,6))
    hp.mollview(V_eff_x1_chi, xsize=800, sub=231, title=r'$V_{eff, x}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_SW_x1_chi, xsize=800, sub=232, title=r'$V^{SW}_{eff, x}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_ISW_x1_chi, xsize=800, sub=233, title=r'$V^{ISW}_{eff, x}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_Dopp_x1_chi, xsize=800, sub=234, title=r'$V^{Dopp}_{eff, x}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_localDopp_x1_chi, xsize=800, sub=235, title=r'$V^{localDopp}_{eff, x}(\mathbf{x}, r_e), z_e = %s$'%ze)

# %%
if 1:
    plt.figure(figsize=(8,6))
    hp.mollview(V_eff_radial_chi, cmap="jet", xsize=800, sub=231, title=r'$V_{eff, r}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_SW_radial_chi, cmap="jet", xsize=800, sub=232, title=r'$V^{SW}_{eff, r}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_ISW_radial_chi, cmap="jet", xsize=800, sub=233, title=r'$V^{ISW}_{eff, r}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_Dopp_radial_chi, cmap="jet", xsize=800, sub=234, title=r'$V^{Dopp}_{eff, r}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_localDopp_radial_chi, cmap="jet", xsize=800, sub=235, title=r'$V^{localDopp}_{eff, r}(\mathbf{x}, r_e), z_e = %s$'%ze)
    hp.mollview(V_eff_Dopp_radial_chi-V_eff_localDopp_radial_chi, cmap="jet", xsize=800, sub=236, title=r'$V^{decDopp}_{eff, r}(\mathbf{x}, r_e), z_e = %s$'%ze)

# %% [markdown]
# # Check symmetries

# %%
if PriPerturbation == 'BubbleCollision':
    theta_deg_test = np.arange(-90,90,1)
    phi_deg_test = 0
    
    theta_test = theta_deg_test * pi / 180.0
    phi_test = phi_deg_test * pi / 180.0
    
    x_e_test = r_e*np.sin(theta_test)*np.cos(phi_test)
    y_e_test = r_e*np.sin(theta_test)*np.sin(phi_test)
    z_e_test = r_e*np.cos(theta_test)

    V_eff_x1_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_x1.real,x_e_test, y_e_test, z_e_test)
    V_eff_x2_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_x2.real,x_e_test, y_e_test, z_e_test)
    V_eff_x3_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_x3.real,x_e_test, y_e_test, z_e_test)
    V_eff_radial_chi_test = TwoDVecField_Radial(V_eff_x1_chi_test, V_eff_x2_chi_test, V_eff_x3_chi_test, theta_test, phi_test)
    
    V_eff_SW_x1_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_SW_x1.real,x_e_test, y_e_test, z_e_test)
    V_eff_SW_x2_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_SW_x2.real,x_e_test, y_e_test, z_e_test)
    V_eff_SW_x3_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_SW_x3.real,x_e_test, y_e_test, z_e_test)
    V_eff_SW_radial_chi_test = TwoDVecField_Radial(V_eff_SW_x1_chi_test, V_eff_SW_x2_chi_test, V_eff_SW_x3_chi_test, theta_test, phi_test)
    
    V_eff_ISW_x1_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_ISW_x1.real,x_e_test, y_e_test, z_e_test)
    V_eff_ISW_x2_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_ISW_x2.real,x_e_test, y_e_test, z_e_test)
    V_eff_ISW_x3_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_ISW_x3.real,x_e_test, y_e_test, z_e_test)
    V_eff_ISW_radial_chi_test = TwoDVecField_Radial(V_eff_ISW_x1_chi_test, V_eff_ISW_x2_chi_test, V_eff_ISW_x3_chi_test, theta_test, phi_test)
    
    V_eff_Dopp_x1_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_Dopp_x1.real,x_e_test, y_e_test, z_e_test)
    V_eff_Dopp_x2_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_Dopp_x2.real,x_e_test, y_e_test, z_e_test)
    V_eff_Dopp_x3_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_Dopp_x3.real,x_e_test, y_e_test, z_e_test)
    V_eff_Dopp_radial_chi_test = TwoDVecField_Radial(V_eff_Dopp_x1_chi_test, V_eff_Dopp_x2_chi_test, V_eff_Dopp_x3_chi_test, theta_test, phi_test)
    
    V_eff_localDopp_x1_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_localDopp_x1.real,x_e_test, y_e_test, z_e_test)
    V_eff_localDopp_x2_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_localDopp_x2.real,x_e_test, y_e_test, z_e_test)
    V_eff_localDopp_x3_chi_test = ThreeDField_on_TwoDSurface(x, y, z, V_eff_localDopp_x3.real,x_e_test, y_e_test, z_e_test)
    V_eff_localDopp_radial_chi_test = TwoDVecField_Radial(V_eff_localDopp_x1_chi_test, V_eff_localDopp_x2_chi_test, V_eff_localDopp_x3_chi_test, theta_test, phi_test)
    np.savetxt('./my_output/A%s_B%s_Xc%s_Ze%s.txt'%(A, B, x_c, ze), np.array([theta_deg_test,V_eff_radial_chi_test]))

# %%
if PriPerturbation == 'BubbleCollision':
    a_test = np.linspace(10e-3, 1, 100)
    fig, ax = plt.subplots(1, 2,figsize=(6*2,4.5*1))
    
    z_plot = 1
    angle, V = np.loadtxt('./my_output/A%s_B%s_Xc%s_Ze%s.txt' %(1e-4, 0, x_c, z_plot))
    ax[0].plot(angle, V, '--')
    angle, V = np.loadtxt('./my_output/A%s_B%s_Xc%s_Ze%s.txt' %(0, 1e-4, x_c, z_plot))
    ax[0].plot(angle, V)
    ax[0].set_xlabel(r'$\theta\ [deg]$')
    ax[0].set_ylabel(r'$v_{eff, r}/c$', rotation=0)
    ax[0].axhline(y=0, c='k', linestyle='--')
    ax[0].axvline(x=0, c='k', linestyle='--')
    ax[0].set_title(r'$z_{e}=%s$' %z_plot)
    ax[1].set_ylim((-1.6e-4, 1.6e-4))
    
    z_plot = 4
    angle, V = np.loadtxt('./my_output/A%s_B%s_Xc%s_Ze%s.txt' %(1e-4, 0, x_c, z_plot))
    ax[1].plot(angle, V, '--')
    angle, V = np.loadtxt('./my_output/A%s_B%s_Xc%s_Ze%s.txt' %(0, 1e-4, x_c, z_plot))
    ax[1].plot(angle, V)
    ax[1].set_xlabel(r'$\theta\ [deg]$')
    ax[1].set_ylabel(r'$v_{eff, r}/c$', rotation=0)
    ax[1].axhline(y=0, c='k', linestyle='--')
    ax[1].axvline(x=0, c='k', linestyle='--')
    ax[1].set_title(r'$z_{e}=%s$' %z_plot)
    ax[1].set_ylim((-1.6e-4, 1.6e-4))

# %%
Vlm_eff_radial_chi = hp.map2alm(V_eff_radial_chi)
Vlm_eff_SW_radial_chi = hp.map2alm(V_eff_SW_radial_chi)
Vlm_eff_ISW_radial_chi = hp.map2alm(V_eff_ISW_radial_chi)
Vlm_eff_Dopp_radial_chi = hp.map2alm(V_eff_Dopp_radial_chi)
Vlm_eff_localDopp_radial_chi = hp.map2alm(V_eff_localDopp_radial_chi)


ClVeff = hp.alm2cl(Vlm_eff_radial_chi)
ClVeff_SW = hp.alm2cl(Vlm_eff_SW_radial_chi)
ClVeff_ISW = hp.alm2cl(Vlm_eff_ISW_radial_chi)
ClVeff_Dopp = hp.alm2cl(Vlm_eff_Dopp_radial_chi)
ClVeff_localDopp = hp.alm2cl(Vlm_eff_localDopp_radial_chi)
ClVeff_SW_ISW = hp.alm2cl(Vlm_eff_SW_radial_chi, Vlm_eff_ISW_radial_chi)
ClVeff_SW_localDopp = hp.alm2cl(Vlm_eff_SW_radial_chi, Vlm_eff_localDopp_radial_chi)
ClVeff_ISW_localDopp = hp.alm2cl(Vlm_eff_ISW_radial_chi, Vlm_eff_localDopp_radial_chi)

# %%
Ls = np.arange(0, 50, 2)
plt.plot(Ls , Ls**2*ClVeff_localDopp[Ls], label='local Dopp')
# plt.xscale('log')
# plt.yscale('log')
plt.legend()
plt.xlabel("$\ell$")
plt.ylabel('${C}^{\mathrm{v_r v_r}}_{\ell}$')
# Out:
# Text(0, 0.5, '${C}^{\\mathrm{v_r v_r}}_{\\ell}$')

# %%
# Calculate theory Clvrvr on light cone slice without width
import config as conf
import my_kszpsz_config. as config
As= config.As
ns = config.ns
# k_sampling = remote_spectra.k_sampling()
k_sampling = np.linspace(1e-5, 1e-2, 10000)
Pk_sampling = remote_spectra.Ppsi(k_sampling, As, ns)

# %%
def get_Clvv_eff(Ls, ks, Pk, ze, Omega_b, Omega_c, w, wa, Omega_K, h, component='localDopp'):
    Clvv_eff = []
    if component == 'localDopp':
        transfer_ksz_k_L = remote_spectra.Transfer_ksz_localDopp_redshift(ks, Ls, ze, Omega_b, Omega_c, w, wa, Omega_K, h)
    if component == 'total':
        transfer_ksz_k_L = remote_spectra.Transfer_ksz_redshift(ks, Ls, ze, Omega_b, Omega_c, w, wa, Omega_K, h)
    
    for L_num in range(len(Ls)):                                                                         
        Clvv_eff.append(np.trapz(ks**2*Pk*transfer_ksz_k_L[:, L_num]**2, ks)/(2*pi)**3)
    return np.array(Clvv_eff)

# %%
Ls = np.arange(0, 50, 2)
Clvv_eff_localDopp_theory = get_Clvv_eff(Ls, k_sampling, Pk_sampling, ze, Omega_b, \
                               Omega_c, w, wa, Omega_K, h, component='localDopp')
Clvv_eff_total_theory = get_Clvv_eff(Ls, k_sampling, Pk_sampling, ze, Omega_b, \
                               Omega_c, w, wa, Omega_K, h, component='total')

# %%
plt.plot(Ls, Ls**2*Clvv_eff_localDopp_theory)
# plt.plot(Ls, Ls**2*Clvv_eff_total_theory)
plt.plot(Ls , Ls**2*ClVeff_localDopp[Ls], label='local Dopp');
plt.legend()
plt.ylim((-1e-7, 7e-7))  
plt.axhline(y=-0, c='k', linestyle='--')

# %%
# how much do the superhorizon modes affect the SNR of the detection of inhomogeneous potential Psi from bubble collision, 
# as they bring in small-ell effective velocity modes which are not exactly zero?
# 
# kSZ tomography simulation 
# similar calculation and simulation for remote quadrupole in appearance of the inhomogeneous potential Psi
